# %% [markdown]
# # TP Programmation en Python
# Turtle est un module graphique du langage de programmation en Python.
# Il est inspiré de la programmation Logo et permet de déplacer une tortue (souvent symbolisée par une flèche) sur l’écran.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#     Pour la cellule de code suivante, appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu dans chaque cellule
# </div>

# %%
from turtle import * # importe toutes les fonctions du module turtle de python

# %% [markdown]
# ## 1 - Découverte

# %% [markdown]
# Il existe différentes instructions en anglais pour faire se déplacer une tortue et tracer des traits.
#
# Résumé des instructions : https://perso.limsi.fr/pointal/_media/python:turtle:turtleref.pdf

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#     Pour la cellule de code suivante, appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu dans chaque cellule
# </div>

# %%
forward(75) # pour avancer la tortue
left(90) # fait tourner la tortue de 90° vers sa gauche

forward(75)
left(90)

forward(75)
left(90)

forward(75)
left(90)

done()

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#    * Modifier le code ci-dessous pour dessiner un rectangle de longueur 100 et de largeur 30 <br>
#
#   ** Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
# code à modifier

forward(75) # pour avancer la tortue
left(90) # fait tourner la tortue de 90° vers sa gauche
forward(75)
left(90)
forward(75)
left(90)
forward(75)
left(90)

done()

# %% [markdown]
# ## 2 - Des boucles pour répéter des instructions :

# %% [markdown]
# Il peut être répétitif d’écrire des lignes de code. On peut utiliser une boucle pour répéter des instructions.
#
# * Démarrer le concours CASTOR en programmation par blocs : https://concours.castor-informatique.fr/?team=SNTturtb
#
# * Choisir l’activité boucle à compteur niveau 2 étoiles
#
# * Faire uniquement la programmation par blocs pour dessiner un hexagone

# %% [markdown]
# A partir de maintenant, on va travailler avec Python et des programmes texte.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
#     une boucle bornée s'écrit avec le mot clé `for` :
#
# ```python
# for i in range(...):        # <-- ici le compteur est i mais ça pourrait être un autre nom
#     instructions            # <-- l'indentation (le décalage) est obligatoire
# ```
# - **Il ne faut pas oublier les  `:`**  à la fin de la première ligne.
# - L'instruction `range()` renvoie une suite d'entiers :
#     - `range(n)` : permet de répéter `n` fois (entiers de 0 inclus à n exclu)
#     - `range(n,m)` : entiers de n inclus à m exclu
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
for i in range(6):
    forward(50)
    left(60)

done()

# %% [markdown]
# 1)	Combien de fois s’exécute la boucle ?
# 2)	Quelles instructions sont exécutées à chaque boucle ?

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * Modifier le code de la cellule suivante pour dessiner un octogone de côté 70 <br>
#
#
#   ** Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
for i in range(       ): # à compléter
    forward(       )    # à compléter
    left(       )   # à compléter

done()

# %% [markdown]
# Que va faire le code suivant ?
# Réfléchir avant d'éxécuter la cellule.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
for i in range(3): 
    forward(100)  
    left(120)  

done()

# %% [markdown]
# ## 3 - Utilisations de fonctions
# Une fonction est un sous-programme qui regroupe plusieurs instructions.
# Les fonctions permettent d’organiser le code principal et d’éviter les répétitions.
#  Une fonction reçoit des données en entrée (appelées paramètres) et renvoie des données en sortie.
#  On lui donne un nom qui servira à l’utiliser à chaque fois qu’on le souhaite.

# %% [markdown]
# Que va faire le code suivant ?
# Réfléchir avant d'éxécuter la cellule.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
# exemple de fonction
def affiche(texte, nombre):
    for i in range(nombre):
        print (texte)

# %% [markdown]
# ce code seul ne fait rien !
# La fonction est maintenant connue de Python.
# Il faut l'utiliser :

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
affiche( "vive les vacances !", 3)

# %% [markdown]
# On veut reproduire une figure composée de multiples triangles.
# On va donc définir une fonction triangle et utiliser ensuite une boucle.
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2023/10-23/15-30-32/fonc.jpg" width=800px>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python contenu
# </div>

# %%
speed(5) #pour faire avancer la tortue plus ou moins vite.  varie de 1 (lent) à 10 (rapide) et 0 est le plus rapide (recommandé)

# ne pas modifier ci-dessous
def triangle(cote):
  #Un exemple de triangle équilatéral
  for i in range(3):
    forward(cote)  #1er côté
    left(120) 
# ________________________________________

# %% [markdown]
# La tortue sait maintenant dessiner des triangles.
# La preuve : exécuter le code suivant

# %%
triangle (100)
triangle (200)

done()

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#   * écrire une boucle dans la cellule suivante pour reproduire le dessin du TP composé de 36 triangles de côté 120 successivement décalés de 10°.
#  <br>
#
#
#   ** Appuyez sur <strong>"shift + entrée"</strong> pour lancer le code Python
# </div>

# %%
for ?????


done()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#  <strong> Le travail est terminé !</strong> <br>
# </div>

# %% [markdown]
# Pour les plus rapides :
# * modifier le code suivant et le tester: nombre de triangles, rotation entre chaque triangle,...

# %%
speed(9)
for i in range (17):
    triangle(10*i)
    left(20)

done()

# %% [markdown]
# Pour les plus rapides : un peu d'aléatoire
# * modifier le code suivant et le tester plusieurs fois pour qu'il effectue une marche au hasard

# %%
from random import randint 

penup()
goto(-200,-200)
setheading(45)
pendown()

for i in range(1000):
  angle = randint(-10,10) # choisit un angle au hasard
  nbpas = randint(-20,20) # choisit un nombre de pas au hasard
  
  left(angle) 
  forward(nbpas)

done()

# %% [markdown]
# * lire le code suivant et le modifier pour dessiner les polygones jusqu'à 10 cotés :

# %%
shape("turtle")

pencolor("black") # change la couleur de tracé des traits
fillcolor("red")  #Change la couleur de remplissage à rouge

up() # lève le crayon pour ne pas dessiner
goto(-100,10) # se déplace au point de coordonnées -100 selon x et +10 selon y
down() # pose le crayon pour dessiner

def polygone(n):               # <-- définition de la fonction que l'on appelle polygone
    for i in range(n):
        forward(40)
        right(360 / n)

# suite à améliorer
        
        
polygone(5)


done()
